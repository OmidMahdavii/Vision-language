# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
# !cp -a /content/drive/MyDrive/Vision-Language-AML/. /content/

# %%
# !pip install -r requirements.txt

# %%
# !python /content/main.py --experiment domain_disentangle --target_domain sketch

# %%
# !cp -a /content/record/domain_disentangle_sketch/. /content/drive/MyDrive/Vision-Language-AML//domain_disentangle_sketch/
